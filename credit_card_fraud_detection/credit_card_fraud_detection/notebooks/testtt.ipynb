# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\durge\Music\credit_card_fraud_detection\credit_card_fraud_detection\data\raw\creditcard.csv")

# %%
df.sample()
# Out:
#           Time        V1       V2        V3        V4        V5        V6  \
# 86858  61428.0 -0.435958  0.96214  1.349364 -0.046605  0.066366 -0.332052
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 86858  0.454276  0.266829 -0.492492  ... -0.186067 -0.521726  0.037076
#
#             V24       V25       V26       V27       V28  Amount  Class
# 86858  0.140551 -0.331721  0.075541  0.251529  0.083989    1.78      0
#
# [1 rows x 31 columns]
